# %%
from google_images_download import google_images_download

# %%
categories= ['automotive','beauty','sport','perfumes','shoes','military','woman','man','kids','digital_electronics']

def download_images(categories):
    response = google_images_download.googleimagesdownload()
    for category in categories:
        arguments = {"keywords":category,"limit":100,"format":"jpg","output_directory": "Images"} #, "print_urls":True}
        paths = response.download(arguments)
        
def json_images(categories):
    response = google_images_download.googleimagesdownload()
    for category in categories:
        #file = open(category+".txt", "w")
        arguments = {"keywords":category,"limit":200,"format":'jpg',# "print_urls":True,
                     "extract_metadata": True, "no_download": True, 
                     "chromedriver": "C:\Program Files (x86)\Google\Chrome\Application\chromedriver.exe"}
        paths = response.download(arguments)
        #file.close()

# %%
json_images(categories)
# Out:
# Item no.: 1 --> Item name = automotive
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting to Print Image URLS
# Image URL: https://ukimediaevents.com/img/covers/aiw.jpg
# Printed url without downloading
# Image URL: https://www.philips.ua/c-dam/b2c/category-pages/lighting/car-lights/master/rebranded/landing/choosebanner_Headlights.jpg
# Printed url without downloading
# Image URL: https://www.synopsys.com/content/dam/synopsys/verification/Veification_SaberAutomotive_spotlight.jpg.imgw.560.336.jpg
# Printed url without downloading
# Image URL: http://www.rubbernews.com/apps/pbcsi.dll/storyimage/RN/20180924/NEWS/180929978/AR/0/AR-180929978.jpg
# Printed url without downloading
# Image URL: http://www.sio-automotive.com/images/suspension.jpg
# Printed url without downloading
# Image URL: https://blokt.com/wp-content/uploads/2018/08/shutterstock_747021289.jpg
# Printed url without downloading
# ...
